# %% [markdown]
# Loading the data by connecting to the dataaset

# %%
from google.colab import drive; drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
path = "/content/drive/MyDrive/personalized_medicine_gene_expression/data/"
df = pd.read_csv(path + "gene_expression_drug_response.csv")

# %% [markdown]
# View the data overview

# %%
print(df.shape); df.head()
# Out:
# (100, 51)
#      Gene_1    Gene_2    Gene_3    Gene_4    Gene_5    Gene_6    Gene_7  \
# 0  5.993428  4.723471  6.295377  8.046060  4.531693  4.531726  8.158426
# 1  5.648168  4.229835  3.646156  6.223353  7.061999  6.862560  3.321565
# 2  2.169259  4.158709  4.314571  3.395445  4.677429  5.808102  8.772372
# 3  5.500986  5.692896  3.639951  5.464507  5.586145  3.571297  8.731549
# 4  5.715575  6.121569  7.166102  7.107604  2.244661  3.124350  6.030071
#
#      Gene_8    Gene_9    Gene_10  ...   Gene_42   Gene_43   Gene_44   Gene_45  \
# 0  6.534869  4.061051   6.085120  ...  5.342737  4.768703  4.397793  2.042956
# 1  4.381575  5.662527   6.951090  ...  6.937290  3.595894  4.344676  4.215784
# 2  5.349156  5.515101   4.851108  ...  7.614286  1.785034  5.369268  5.519766
# 3  5.947666  2.617393   6.313107  ...  6.712798  5.428187  2.508522  5.346362
# 4  6.027572  6.030095  12.705463  ...  4.770527  6.009975  6.731510  2.599407
#
# ...

# %% [markdown]
# Check for  missing values

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Check Class Balance

# %%
df['Drug_Response'].value_counts()
# Out:
# Drug_Response
# 0    55
# 1    45
# Name: count, dtype: int64

# %% [markdown]
# Basic Summary stats

# %%
df.describe().T
# Out:
#                count      mean       std       min       25%       50%  \
# Gene_1         100.0  4.762611  1.951736 -0.406465  3.548365  4.837167
# Gene_2         100.0  5.186645  2.096691 -0.792511  3.787281  5.224314
# Gene_3         100.0  5.076771  1.975593 -0.813976  3.644605  5.073968
# Gene_4         100.0  5.163806  1.842850  1.338734  3.580254  5.308339
# Gene_5         100.0  4.839331  1.966228 -0.858897  3.596823  4.797234
# Gene_6         100.0  4.985369  2.164500 -0.182085  3.627332  4.839060
# Gene_7         100.0  4.876776  1.977434 -0.408783  3.553607  4.893846
# Gene_8         100.0  5.161689  2.052822 -0.709253  3.978037  5.269566
# Gene_9         100.0  5.167427  1.814032 -0.208428  3.998766  5.530405
# Gene_10        100.0  5.448012  1.863898  1.260367  4.167462  5.387698
# Gene_11        100.0  4.818436  1.776262  0.001189  3.660015  4.727235
# Gene_12        100.0  5.035323  2.037277 -0.697085  3.534279  4.962394
# ...

# %% [markdown]
# Correlation Heatmap

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.iloc[:, :10].corr(), annot=True, cmap='coolwarm')
plt.title("Gene Correlation (First 10)")
plt.tight_layout()
plt.savefig(path + "correlation_heatmap.png")  # Saves to Drive
plt.show()

# %% [markdown]
# PCA for Visualization

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

X = df.drop('Drug_Response', axis=1)
y = df['Drug_Response']

X_scaled = StandardScaler().fit_transform(X)
X_pca = PCA(n_components=2).fit_transform(X_scaled)

# %%
import seaborn as sns; import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
sns.scatterplot(x=X_pca[:,0], y=X_pca[:,1], hue=y)
plt.title("PCA Projection of Gene Expression")
plt.tight_layout()
plt.savefig(path + "pca_projection.png")  # Save to Drive
plt.show()
